# %% [markdown]
# # Measuring correlation
#
#
# - dataset creation and exploration
# - Pearson correlation
# - Spearman correlation

# %% [markdown]
# ## a. Create and explore the data set

# %%
# Import the required libraries.
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Create an expanded data set with more data points.
url ='https://raw.githubusercontent.com/fourthrevlxd/cam_dsb/main/HLW.csv'

# Convert to a Pandas DataFrame.
df = pd.read_csv(url)

# %%
# View the DataFrame.
print(df.shape)
df
# Out:
# (269, 2)
#      age  participation
# 0     25             10
# 1     30             12
# 2     35             14
# 3     40             15
# 4     45             17
# ..   ...            ...
# 264   47             18
# 265   37              9
# 266   46             14
# 267   69             28
# 268   30             18
#
# [269 rows x 2 columns]

# %%
# Exploratory data analysis (EDA).
# Descriptive Statistics.
df.describe(include = "all")
# Out:
#               age  participation
# count  269.000000     269.000000
# mean    46.546468      18.070632
# std     14.990628       6.712001
# min     15.000000       6.000000
# 25%     35.000000      13.000000
# 50%     46.000000      17.000000
# 75%     57.000000      23.000000
# max     87.000000      37.000000

# %%
# Visualise possible correlation.
plt.figure(figsize=(10, 8))

# Create a scatterplot.
plt.scatter(df['age'],
            df['participation'],
            c='b')

plt.title('Scatterplot')
plt.xlabel('Participant age')
plt.ylabel('Programme participation')

# Show the plot.
plt.show()

# %% [markdown]
# ## b. Pearson correlation

# %%
# Import the required library.
from scipy.stats import pearsonr

# Calculate Pearson correlation.
pearson_corr, pearson_p_value = pearsonr(df['age'],
                                         df['participation'])

# View the output.
print("\nPearson correlation coefficient:", pearson_corr)
print("Pearson p-value:", pearson_p_value)
# Out:
# Pearson correlation coefficient: 0.9064812509667247
# Pearson p-value: 5.7093703526174894e-102

# %%
# Visualise a heatmap to display the correlation matrix.
plt.figure(figsize=(10, 8))
corr_matrix_pearson = df.corr(method='pearson')

sns.heatmap(corr_matrix_pearson,
            annot=True,
            cmap='coolwarm',
            linewidths=0.5,
            annot_kws={"fontsize": 16, "fontweight": "bold"})

plt.title('Pearson correlation')
plt.show()

# %% [markdown]
# ## c. Create and explore the data set

# %%
# Import the data set.
url ='https://raw.githubusercontent.com/fourthrevlxd/cam_dsb/main/thurber.csv'

# Convert to a Pandas DataFrame.
df2 = pd.read_csv(url)

# %%
# View the DataFrame.
print(df2.shape)
df2
# Out:
# (37, 2)
#          y      x
# 0     80.6 -3.070
# 1     84.2 -2.980
# 2     87.3 -2.920
# 3     87.2 -2.910
# 4     89.1 -2.840
# 5     89.6 -2.800
# 6     89.9 -2.700
# 7     90.1 -2.700
# 8     92.4 -2.630
# 9     95.9 -2.480
# 10   101.0 -2.360
# 11   101.0 -2.320
# 12   402.0 -1.500
# 13   391.0 -1.460
# 14   568.0 -1.270
# 15   635.0 -1.210
# 16   733.0 -1.100
# 17   759.0 -1.050
# 18   894.0 -0.915
# 19   991.0 -0.714
# 20  1090.0 -0.566
# 21  1080.0 -0.545
# 22  1120.0 -0.400
# 23  1180.0 -0.309
# 24  1260.0 -0.109
# 25  1270.0 -0.103
# 26  1290.0  0.010
# 27  1330.0  0.119
# 28  1350.0  0.377
# 29  1410.0  0.790
# 30  1430.0  0.963
# 31  1420.0  1.010
# 32  1440.0  1.120
# 33  1460.0  1.570
# 34  1470.0  1.840
# 35  1450.0  2.050
# 36  1460.0  2.200

# %%
# Descriptive statistics.
df2.describe(include = "all")
# Out:
#                  y          x
# count    37.000000  37.000000
# mean    783.008108  -0.862486
# std     564.118607   1.608742
# min      80.600000  -3.070000
# 25%      95.900000  -2.480000
# 50%     894.000000  -0.915000
# 75%    1330.000000   0.119000
# max    1470.000000   2.200000

# %%
# Visualise possible correlation.
plt.figure(figsize=(10, 8))

# Create a scatterplot.
plt.scatter(df2['x'],
            df2['y'],
            c='b')

plt.title('Scatterplot')
plt.xlabel('Predictor variable}')
plt.ylabel('Response variable')

# Show the plot.
plt.show()

# %% [markdown]
# ## d. Spearman correlation

# %%
# Import the required library.
from scipy.stats import spearmanr

# Calculate the Spearman correlation.
spearman_corr, spearman_p_value = spearmanr(df2['x'],
                                            df2['y'])

# View the output.
print("\nSpearman correlation coefficient:", spearman_corr)
print("Spearman p-value:", spearman_p_value)
# Out:
# Spearman correlation coefficient: 0.9974509472739708
# Spearman p-value: 9.949797420251718e-42

# %%
# Visualise using a correlation matrix heatmap.
plt.figure(figsize=(10, 8))
corr_matrix_spearman = df2.corr(method='spearman')

sns.heatmap(corr_matrix_spearman,
            annot=True,
            cmap='coolwarm',
            linewidths=0.5,
            annot_kws={"fontsize": 16, "fontweight": "bold"})

plt.title('Spearman correlation')

# Show the plot.
plt.show()
